# %% [markdown]
# ## Data Analasys Task

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn.preprocessing as skl_pre
import sklearn.linear_model as skl_lm
import sklearn.discriminant_analysis as skl_da
import sklearn.neighbors as skl_nb
import sklearn.model_selection as skl_ms

# %%
# Load the data
path = '/Users/jakobnilsson/Library/CloudStorage/OneDrive-Uppsalauniversitet/UU/SMask/Project/training_data_vt2025.csv'
data  = pd.read_csv(path, dtype={'ID': str}).dropna().reset_index(drop=True)
data.head()
# Out:
#    hour_of_day  day_of_week  month  holiday  weekday  summertime  temp   dew  \
# 0            5            5      1        0        0           0  -7.2 -15.0
# 1           21            4      1        0        1           0  -1.3 -12.8
# 2           21            3      8        0        1           1  26.9  21.8
# 3            1            6      1        0        0           0   3.1  -4.0
# 4           17            0      3        0        1           0  11.7 -11.4
#
#    humidity  precip  snow  snowdepth  windspeed  cloudcover  visibility  \
# 0     53.68     0.0     0        0.0       16.3        31.6        16.0
# 1     40.97     0.0     0        0.0       23.9        85.7        16.0
# 2     73.39     0.0     0        0.0        0.0        81.1        16.0
# 3     59.74     0.0     0        0.0       19.2         0.0        16.0
# 4     18.71     0.0     0        0.0       10.5        44.6        16.0
#
#     increase_stock
# 0  low_bike_demand
# 1  low_bike_demand
# ...

# %%
# Categorical variables
hours = data['hour_of_day']
days = data['day_of_week']
months = data['month']
holidays = data['holiday']
weekdays = data['weekday']
summer = data['summertime']

# Numerical variables
temp = data['temperature']
wind = data['wind_speed']
rain = data['rainfall']
dew = data['dew']
humidity = data['humidity']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 demand = data['increase_stock']
# ----> 3 plt.boxplot(demand, data['cloudcover'])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/pyplot.py:2833, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2801 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2802 def boxplot(
#    2803     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    2831     data=None,
#    2832 ) -> dict[str, Any]:
# -> 2833     return gca().boxplot(
#    2834         x,
#    2835         notch=notch,
#    2836         sym=sym,
# ...

# %%
data.describe()
# Out:
#        hour_of_day  day_of_week        month      holiday      weekday  \
# count   1600.00000  1600.000000  1600.000000  1600.000000  1600.000000
# mean      11.37125     3.022500     6.468750     0.033125     0.710000
# std        6.94837     2.012965     3.454741     0.179019     0.453904
# min        0.00000     0.000000     1.000000     0.000000     0.000000
# 25%        5.00000     1.000000     3.000000     0.000000     0.000000
# 50%       12.00000     3.000000     6.000000     0.000000     1.000000
# 75%       17.00000     5.000000     9.000000     0.000000     1.000000
# max       23.00000     6.000000    12.000000     1.000000     1.000000
#
#        summertime         temp          dew     humidity       precip    snow  \
# count  1600.00000  1600.000000  1600.000000  1600.000000  1600.000000  1600.0
# mean      0.64375    15.210313     7.750750    63.927844     0.122042     0.0
# std       0.47904     9.264785    10.026459    19.079419     0.920600     0.0
# ...
